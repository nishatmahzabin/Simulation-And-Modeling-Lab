# %% [markdown]
# Simulation and Modeling Lab
#
# Course Code: CSE 413
#
# Name: Md. Nishat Mahzabin
#
# ID: 0432310005101095
#
# Sec: 7B2;
#
#  Batch: 53
#
# Semester: Spring 2026
#
# Assignment No.: 01

# %% [markdown]
# **Assignment Tasks**
#
# Assignment 1: Basic Matrix Operations
#
#
# *   Create two 3×3 matrices with random integers in Python.
#
# *   Perform addition, subtraction, and multiplication operations on these matrices.
# * Compute the determinant, inverse, and rank of one of the matrices.
#
#
#
#
#
#
#
#
#
# Assignment 2: Matrix Plotting and Visualization
#
#   Generate and Plot Two Random Vectors:
#
#
# *  Create two vectors, each containing 15 random floats of your choice.
#
# * Plot these vectors on the same graph using matplotlib to compare how they look.
# *  Label the axes appropriately and give the plot a title.

# %% [markdown]
# # Necessary Libraries

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Assignment - 01

# %%
import numpy as np
# # Random Matrix
a_mat = np.random.randint(0,10,size=(3,3))
b_mat = np.random.randint(0,10,size=(3,3))

# Sum of 2 Random Matrix
sum_mat = a_mat + b_mat

# Subtraction of 2 Random Matrix
sub_mat = a_mat - b_mat

# Multiplication of 2 Random Matrix
mul_mat = np.dot(a_mat,b_mat)

# Matrix Diterminent
det_mata = np.linalg.det(a_mat)
det_matb = np.linalg.det(b_mat)

# Matrix Inverse for a
if(np.linalg.det(a_mat)!=0):
  inv_mata = np.linalg.inv(a_mat)
else:
  print("Matrix is Singular")

# Matrix Inverse for b
if(np.linalg.det(b_mat)!=0):
  inv_matb = np.linalg.inv(b_mat)
else:
  print("Matrix is Singular")

# Rank of the Matrix
rank_mata = np.linalg.matrix_rank(a_mat)
rank_matb = np.linalg.matrix_rank(b_mat)

# Print Functions
print("Matrix A: \n",a_mat,"\n")
print("Matrix B: \n",b_mat,"\n")
print("Sum of Matrix: \n",sum_mat,"\n")
print("Subtraction of Matrix: \n",sub_mat,"\n")
print("Multiplication of Matrix: \n",mul_mat,"\n")
print("Matrix Determinant of Mat A: \n",det_mata,"\n")
print("Matrix Determinant of Mat B: \n",det_matb,"\n")

# It's possible for a matrix to be singular, so check if inv_mata and inv_matb are defined before printing
if 'inv_mata' in locals():
    print("Matrix Inverse of Mat A: \n",inv_mata,"\n")
else:
    print("Matrix A inverse not computed (singular)\n")

if 'inv_matb' in locals():
    print("Matrix Inverse of Mat B: \n",inv_matb,"\n")
else:
    print("Matrix B inverse not computed (singular)\n")

print("Matrix Rank of Mat A: \n",rank_mata,"\n")
print("Matrix Rank of Mat B: \n",rank_matb,"\n")
# Out:
# Matrix A:
#  [[8 7 8]
#  [7 2 9]
#  [5 5 4]]
#
# Matrix B:
#  [[5 9 0]
#  [1 4 7]
#  [6 0 6]]
#
# Sum of Matrix:
#  [[13 16  8]
#  [ 8  6 16]
#  [11  5 10]]
#
# Subtraction of Matrix:
#  [[ 3 -2  8]
#  [ 6 -2  2]
#  [-1  5 -2]]
#
# Multiplication of Matrix:
#  [[ 95 100  97]
#  [ 91  71  68]
#  [ 54  65  59]]
#
# Matrix Determinant of Mat A:
#  23.0
#
# Matrix Determinant of Mat B:
#  444.0
#
# Matrix Inverse of Mat A:
#  [[-1.60869565  0.52173913  2.04347826]
#  [ 0.73913043 -0.34782609 -0.69565217]
#  [ 1.08695652 -0.2173913  -1.43478261]]
#
# Matrix Inverse of Mat B:
#  [[ 0.05405405 -0.12162162  0.14189189]
#  [ 0.08108108  0.06756757 -0.07882883]
#  [-0.05405405  0.12162162  0.02477477]]
#
# Matrix Rank of Mat A:
#  3
#
# Matrix Rank of Mat B:
#  3

# %% [markdown]
# ## Assignment - 02

# %%
import matplotlib.pyplot as plt
import numpy as np
# Random Matrix with float
A = np.random.uniform(11,30, size=(5,3))
B = np.random.uniform(31,40, size=(5,3))

print("Matrix A: \n",A,"\n")
print("Matrix B: \n",B,"\n")

# Flattem 1D Array
A_flat = A.flatten()
B_flat = B.flatten()

print("Flattened Matrix A: \n",A_flat,"\n")
print("Flattened Matrix B: \n",B_flat,"\n")

# Create an Index for x-Axis
x = np.arange(len(A_flat))

# Line Plot
plt.plot(x, A_flat, marker = "o", linestyle = "-", label="Matrix A")
plt.plot(x, B_flat, marker = "s", linestyle = "--", label="Matrix B")

# Label and Title
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Line Graph of Float Flatten Matrices A and B")
plt.legend()
plt.grid(True)

# Show the Plot
plt.show()
# Out:
# Matrix A:
#  [[13.70781591 13.13318564 18.01026199]
#  [24.8725927  16.0048342  24.4986461 ]
#  [14.06881779 12.79348284 17.50408999]
#  [20.50266669 16.2846381  19.51339829]
#  [12.05477238 19.38192974 19.82648331]]
#
# Matrix B:
#  [[36.97754319 31.51220657 39.93160481]
#  [38.19241135 38.50050876 31.25520254]
#  [33.71750546 35.0629385  39.65960348]
#  [37.35224947 39.63652931 39.7253463 ]
#  [32.93580028 31.39312735 33.03392524]]
#
# Flattened Matrix A:
#  [13.70781591 13.13318564 18.01026199 24.8725927  16.0048342  24.4986461
#  14.06881779 12.79348284 17.50408999 20.50266669 16.2846381  19.51339829
#  12.05477238 19.38192974 19.82648331]
#
# Flattened Matrix B:
#  [36.97754319 31.51220657 39.93160481 38.19241135 38.50050876 31.25520254
#  33.71750546 35.0629385  39.65960348 37.35224947 39.63652931 39.7253463
#  32.93580028 31.39312735 33.03392524]
